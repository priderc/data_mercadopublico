# %%
import mp

# %%
df = mp.load_data()

# %%
mp.print_result(df, 'hidráulica')
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defaultColumnWidth': 150, 'rowHeight': 28, 'enableColumnReorder': False, 'enableTextSelectionOnCells': True, 'editable': True, 'autoEdit': False, 'explicitInitialization': True, 'maxVisibleRows': 15, 'minVisibleRows': 8}, precision=5)

# %%
mp.get_result(df, 'hidráulica')
# Out:
#             Textbox36                                             TipoLC  \
# 3        3468-65-LP17  Licitación Pública igual o superior a 1.000 UT...
# 4        3468-64-LE17  Licitación Pública igual o superior a 100 UTM ...
# 6        2859-79-LP17  Licitación Pública igual o superior a 1.000 UT...
# 45       4362-18-LE17  Licitación Pública igual o superior a 100 UTM ...
# 149      1090-30-LE17  Licitación Pública igual o superior a 100 UTM ...
# 150     2450-675-L117              Licitación pública inferior a 100 UTM
# 158      1090-31-LE17  Licitación Pública igual o superior a 100 UTM ...
# 159      1090-29-LE17  Licitación Pública igual o superior a 100 UTM ...
# 193      2597-76-LQ17  Licitación Pública igual o superior a 2.000 UT...
# 557     2981-128-LR17                Licitación Pública Mayor a 5000 UTM
# 581       4963-9-LP17  Licitación Pública igual o superior a 1.000 UT...
# 699     5407-146-LQ17  Licitación Pública igual o superior a 2.000 UT...
# ...

# %%
mp.print_codes(df, 'hidráulica')
# Out:
# 70151506
# 70151507
# 70151802
# 70151805
# 70171707
# 72131702
# 80161502
# 81101505
# 83101505
# 92101501
# 101101001
# 101111081

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20303 entries, 0 to 20302
# Data columns (total 16 columns):
# Textbox36            20303 non-null object
# TipoLC               20143 non-null object
# Textbox37            20303 non-null object
# Textbox38            20303 non-null object
# Textbox39            20303 non-null object
# citName              20299 non-null object
# Textbox40            20303 non-null object
# FechaCierre1         20156 non-null object
# rbiDescription       19895 non-null object
# rbiGoodAndService    20303 non-null int64
# Unidad_de_Medida     20300 non-null object
# Cantidad             20303 non-null float64
# ProductoName         20303 non-null object
# Level1               20303 non-null object
# Level2               20303 non-null object
# Level3               20303 non-null object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 2.5+ MB
