# %%
import mp

# %%
mp.main()

# %%
df = mp.get_data('tmp')

# %%
df.columns
# Out:
# Index([u'Textbox36', u'TipoLC', u'Textbox37', u'Textbox38', u'Textbox39',
#        u'citName', u'Textbox40', u'FechaCierre1', u'rbiDescription',
#        u'rbiGoodAndService', u'Unidad_de_Medida', u'Cantidad', u'ProductoName',
#        u'Level1', u'Level2', u'Level3'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17698 entries, 0 to 17697
# Data columns (total 16 columns):
# Textbox36            17698 non-null object
# TipoLC               17698 non-null object
# Textbox37            17698 non-null object
# Textbox38            17698 non-null object
# Textbox39            17698 non-null object
# citName              17614 non-null object
# Textbox40            17698 non-null object
# FechaCierre1         17559 non-null object
# rbiDescription       17353 non-null object
# rbiGoodAndService    17698 non-null int64
# Unidad_de_Medida     17695 non-null object
# Cantidad             17698 non-null float64
# ProductoName         17698 non-null object
# Level1               17698 non-null object
# Level2               17698 non-null object
# Level3               17698 non-null object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 2.2+ MB

# %%
mp.print_codes(df, 'hidráulica')
# Out:
# array([ 22101524.,  31251501.,  70131502.,  70171707.,  72102302.,
#         72131702.,  81101501.,  81101507.,  81101513.,  83101504.,
#         83101505.])

# %%
mp.print_result(df, 'hidráulica')
# Out:
#             Textbox36                                             TipoLC  \
# 60      619284-1-LQ17  Licitación Pública igual o superior a 2.000 UT...
# 336      1669-24-L117              Licitación pública inferior a 100 UTM
# 337      1669-24-L117              Licitación pública inferior a 100 UTM
# 338      1669-24-L117              Licitación pública inferior a 100 UTM
# 339      1669-24-L117              Licitación pública inferior a 100 UTM
# 470       2766-5-L117              Licitación pública inferior a 100 UTM
# 471       2766-5-L117              Licitación pública inferior a 100 UTM
# 500       2766-4-L117              Licitación pública inferior a 100 UTM
# 512       2766-3-L117              Licitación pública inferior a 100 UTM
# 518       2628-1-L117              Licitación pública inferior a 100 UTM
# 520       2628-1-L117              Licitación pública inferior a 100 UTM
# 524       2628-1-L117              Licitación pública inferior a 100 UTM
# ...

# %%
mp.get_result(df, 'hidráulica')
